# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import itertools

# %%
# Reading the data 
data=pd.read_csv("D://Diabetes_Prediction//diabetes.csv")

# %%
#displaying the data
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#describing the data
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# finding the null values in data
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# data type used
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # Data Visualisation

# %%
#Visualising the Count of Target Variable
sns.countplot(x='Outcome',data=data)
plt.show()

# %%
# Count of pregnancies
sns.countplot(data['Pregnancies'])
plt.show()
# we can see the outliers in the data

# %%
dat=data.loc[data['Pregnancies']>10]
dat
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 24            11      143             94             33      146  36.6
# 28            13      145             82             19      110  22.2
# 36            11      138             76              0        0  33.2
# 72            13      126             90              0        0  43.4
# 86            13      106             72             54        0  36.6
# 88            15      136             70             32      110  37.1
# 159           17      163             72             41      114  40.9
# 193           11      135              0              0        0  52.3
# 215           12      151             70             40      271  41.8
# 254           12       92             62              7      258  27.6
# 259           11      155             76             28      150  33.3
# 274           13      106             70              0        0  34.2
# 298           14      100             78             25      184  36.6
# 323           13      152             90             33       29  26.8
# 333           12      106             80              0        0  23.6
# 357           13      129              0             30        0  39.9
# 358           12       88             74             40       54  35.3
# 375           12      140             82             43      325  39.2
# 436           12      140             85             33        0  37.4
# 455           14      175             62             30        0  33.6
# 510           12       84             72             31        0  29.7
# 518           13       76             60              0        0  32.8
# 558           11      103             68             40        0  46.2
# 559           11       85             74              0        0  30.1
# 582           12      121             78             17        0  26.5
# 590           11      111             84             40        0  46.8
# 614           11      138             74             26      144  36.1
# 635           13      104             72              0        0  31.2
# 648           11      136             84             35      130  28.3
# 658           11      127            106              0        0  39.0
# 691           13      158            114              0        0  42.3
# 740           11      120             80             37      150  42.3
# 744           13      153             88             37      140  40.6
# 745           12      100             84             33      105  30.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 24                      0.254   51        1
# 28                      0.245   57        0
# 36                      0.420   35        0
# 72                      0.583   42        1
# 86                      0.178   45        0
# 88                      0.153   43        1
# 159                     0.817   47        1
# 193                     0.578   40        1
# 215                     0.742   38        1
# 254                     0.926   44        1
# 259                     1.353   51        1
# 274                     0.251   52        0
# 298                     0.412   46        1
# 323                     0.731   43        1
# 333                     0.137   44        0
# 357                     0.569   44        1
# 358                     0.378   48        0
# 375                     0.528   58        1
# 436                     0.244   41        0
# 455                     0.212   38        1
# 510                     0.297   46        1
# 518                     0.180   41        0
# 558                     0.126   42        0
# 559                     0.300   35        0
# 582                     0.259   62        0
# 590                     0.925   45        1
# 614                     0.557   50        1
# 635                     0.465   38        1
# 648                     0.260   42        1
# 658                     0.190   51        0
# 691                     0.257   44        1
# 740                     0.785   48        1
# 744                     1.174   39        0
# 745                     0.488   46        0

# %%
sns.countplot(dat['Pregnancies'])

# %%
#CLosure look at glucose
plt.hist(data['Glucose'],bins=10,edgecolor='black')
plt.xlabel('Range')
plt.ylabel("Glucose Level")
plt.title('Closure look at Glucose')
plt.show()

# %%
# Outliers in glucose
dt=data.loc[data['Glucose']<25]
dt.shape[0]
# Out:
# 5

# %%
print("Before concatenation rows :" ,dat.shape[0])
dat=dat.append(dt)
print("After concatenation rows :" ,dat.shape[0])
# Out:
# Before concatenation rows : 34
# After concatenation rows : 39

# %%
# Closure look at BloodPressure
plt.hist(data['BloodPressure'],bins=10,edgecolor='black')
plt.xlabel('Range')
plt.ylabel("BloodPressure")
plt.title('Closure look at BloodPressure')
plt.show()

# %%
dt=data.loc[data['BloodPressure']<25]
dt.shape[0]
# Out:
# 36

# %%
print("Before concatenation rows :" ,dat.shape[0])
dat=dat.append(dt)
print("After concatenation rows :" ,dat.shape[0])
# Out:
# Before concatenation rows : 39
# After concatenation rows : 75

# %%
# closure look at Skinthicknes
plt.hist(data['SkinThickness'],bins=10,edgecolor='black')
plt.xlabel('Range')
plt.ylabel("SkinThickness Level")
plt.title('Closure look at Skinthickness')
plt.show()

# %%
dt=data.loc[data['SkinThickness']>80]
dt.shape[0]
# Out:
# 1

# %%
print("Before concatenation rows :" ,dat.shape[0])
dat=dat.append(dt)
print("After concatenation rows :" ,dat.shape[0])
# Out:
# Before concatenation rows : 75
# After concatenation rows : 76

# %%
# closure look at 
plt.hist(data['Insulin'],bins=10,edgecolor='black')
plt.xlabel('Range')
plt.ylabel("Insulin")
plt.title('Closure look at Insulin')
plt.show()

# %%
dt=data.loc[data['Insulin']>600]
dt.shape[0]
# Out:
# 3

# %%
print("Before concatenation rows :" ,dat.shape[0])
dat=dat.append(dt)
print("After concatenation rows :" ,dat.shape[0])
# Out:
# Before concatenation rows : 76
# After concatenation rows : 79

# %%
# closure look at BMI
plt.hist(data['BMI'],bins=10,edgecolor='black')
plt.xlabel('Range')
plt.ylabel("BMI Level")
plt.title('Closure look at BMI')
plt.show()

# %%
dt=data.loc[data['BMI']<10]
dt.shape[0]
# Out:
# 11

# %%
print("Before concatenation rows :" ,dat.shape[0])
dat=dat.append(dt)
print("After concatenation rows :" ,dat.shape[0])
# Out:
# Before concatenation rows : 79
# After concatenation rows : 90

# %%
# Collecting the outliers for furthur studies
dat.to_csv("D://Diabetes_Prediction//Outliers.csv")

# %%
# closure look at Age
plt.hist(data['Age'],bins=10,edgecolor='black')
plt.xlabel('Range')
plt.ylabel("Age Level")
plt.title('Closure look at Age')
plt.show()

# %%
# closure look at only positive cases of Diabetes with Outliers
diab1=data[data['Outcome']==1]
columns=data.columns[:8]
plt.subplots(figsize=(18,15))
length=len(columns)
for i,j in itertools.zip_longest(columns,range(length)):
    plt.subplot((length/2),3,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    diab1[i].hist(bins=10,edgecolor='black')
    plt.title(i)
plt.show()

# %%
data1=data.copy()

# %%
data1=data1.loc[data1['Pregnancies']<=10]
data1=data1.loc[data1['Glucose']>=25]
data1=data1.loc[data1['BloodPressure']>=25]
data1=data1.loc[data1['SkinThickness']<=80]
data1=data1.loc[data1['Insulin']<=600]
dt=data.loc[data['BMI']>10]

# %%
data1.shape[0]
# Out:
# 691

# %%
# closure look at only positive cases of Diabetes without Outliers
diab1=data1[data1['Outcome']==1]
columns=data1.columns[:8]
plt.subplots(figsize=(18,15))
length=len(columns)
for i,j in itertools.zip_longest(columns,range(length)):
    plt.subplot((length/2),3,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    diab1[i].hist(bins=10,edgecolor='black',color='lightblue')
    plt.title(i)
plt.show()

# %% [markdown]
# # Validating the visualisation

# %%
# Visualising the preprocessed data to check biasing of the class in each attribute
sns.pairplot(data=data1,hue='Outcome',diag_kind='kde')
plt.show()
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\acer\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\acer\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\acer\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
# Correlation of the preprocessed data
sns.heatmap(data1.corr(),annot=True,cmap='RdYlGn')
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# # Data Modelling

# %%
#importing models through sklearn
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import KFold

# %%
outcome=data1['Outcome']
data=data1[data1.columns[:8]]
train,test=train_test_split(data1,test_size=0.3,random_state=0,stratify=data1['Outcome'])
train_X=train[train.columns[:8]]
test_X=test[test.columns[:8]]
train_Y=train['Outcome']
test_Y=test['Outcome']

# %%
print("Train data :",train_X.shape,"\nTrain Output :",train_Y.shape,"\nTest Data :",test_X.shape,"\nTest Output :",test_Y.shape)
# Out:
# Train data : (483, 8)
# Train Output : (483,)
# Test Data : (208, 8)
# Test Output : (208,)

# %%
model1 = svm.SVC()
model1.fit(train_X,train_Y)
prediction=model1.predict(test_X)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction,test_Y)*100)
# Out:
# The accuracy of the Logistic Regression is 66.82692307692307
# C:\Users\acer\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
model2=DecisionTreeClassifier()
model2.fit(train_X,train_Y)
prediction=model2.predict(test_X)
print('The accuracy of the Decision Tree is',metrics.accuracy_score(prediction,test_Y)*100)
# Out:
# The accuracy of the Decision Tree is 73.5576923076923

# %%
model3 = KNeighborsClassifier()
model3.fit(train_X,train_Y)
prediction=model3.predict(test_X)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction,test_Y)*100)
# Out:
# The accuracy of the Logistic Regression is 75.0

# %% [markdown]
# # Cross validation

# %%
dat=data1.copy()
del dat['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(dat,data1['Outcome'],test_size=0.4,random_state=42, stratify=data1['Outcome'])

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold

test_scores = []
train_scores = []
validation_scores = []
X_train_values = X_train.values
y_train_values = y_train.values

## cross validation with KFold algorithm
kfold = KFold(5, shuffle=True, random_state=42)
for i in range(1,15):

    knn = KNeighborsClassifier(i)

    tr_scores = []
    ts_scores = []
    for train_ix, test_ix in kfold.split(X_train_values):
        # define train/test X/y
        X_train_fold, y_train_fold = X_train_values[train_ix],y_train_values[train_ix]
        X_test_fold, y_test_fold = X_train_values[test_ix], y_train_values[test_ix]
        knn.fit(X_train_fold,y_train_fold)
        ts_scores.append(knn.score(X_test_fold,y_test_fold))
        tr_scores.append(knn.score(X_train_fold,y_train_fold))
    validation_scores.append(np.mean(ts_scores))
    train_scores.append(np.mean(tr_scores))
    test_scores.append(knn.score(X_test,y_test))

# %%
plt.figure(figsize=(12,5))
p = sns.lineplot(range(1,15),train_scores,marker='*',label='Train Score')
p = sns.lineplot(range(1,15),test_scores,marker='o',label='Test Score')
p = sns.lineplot(range(1,15),validation_scores,marker='v',label='Validation Score')

# %% [markdown]
# # Confusion Matrix

# %%
y_pred = knn.predict(X_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %% [markdown]
# # Custom Function to Predict

# %%
def remedy(aa):
    jj=str(input("Enter your name : "))
    jk=str(input("Enter the Gender : "))
    ll="Does--> \n 1.Exercise Properly \n 2.Control your carbon intake \n 3.Increase your carbon Intake \n 4.Stay Hydarated \n 5.Choose food with low glycemic level\n\nSome Natural ways-->\nBilberry extract\nBitter melon\nCinnamon\nFenugreek\nGinger\nOkra"
    file = open("D://Diabetes_Prediction//Report.txt","w") 
    s="Name : " +jj+"\n"
    ss="Gender : "+jk+"\n"
    sss="Diabetes Status : "+aa+"\n"
    file.write(s) 
    file.write(ss) 
    file.write(sss)
    file.write(ll) 
    file.close()
    print("Your Report Has Been Generated..")

# %%
def find(find_result):
    m=0
    if(m==0):
        z=int(input("Press 1 to Continue :-"))
        if(z==1):
            p=model1.predict(find_result)
            print("The Predition by SVM : ",p)
            q=model2.predict(find_result)
            print("The Predition by Decision Tree : ",q)
            r=model3.predict(find_result)
            print("The Predition by KNN : ",r)
            ww=p+q+r
            if(ww>1.7):
                print("Higher Possibility of Diabetes")
                aa="Higher Possibility"
                remedy(aa)
            else:
                print("Lower possibility of Diabetes")
                aa="Lower Possibility"
                remedy(aa)
            m=m+1
        else:
            print("Warning:Please select Defined Number!!")

# %%
def Value():
    print(" Welcome to the Diabetes Detection Mechanism ")
    print("======================================================")
    a=int(input("Enter the number of Pregnancies(1-10) : "))
    b=int(input("Enter the Glucose Level(80-200): "))
    c=int(input("Enter the BloodPressure Recorded(30-110) : "))
    d=int(input("Enter the SkinThickness(0-60) : "))
    e=int(input("Enter the Insulin Amount(0-600) : "))
    f=int(input("Enter the BMI Index(20-60) : "))
    g=float(input("Enter the DiabetesPedigreeFunction(0-1) : "))
    h=int(input("Enter the Age : "))
    find_result=pd.DataFrame({"Pregnancies":[a],"Glucose":[b],"BloodPressure":[c],"SkinThickness":[d],"Insulin":[e],"BMI":[f],"DiabetesPedigreeFunction":[g],"Age":[h]})
    find(find_result)

# %%
Value()
# Out:
#  Welcome to the Diabetes Detection Mechanism
# ======================================================
# Enter the number of Pregnancies(1-10) : 4
# Enter the Glucose Level(80-200): 111
# Enter the BloodPressure Recorded(30-110) : 56
# Enter the SkinThickness(0-60) : 23
# Enter the Insulin Amount(0-600) : 544
# Enter the BMI Index(20-60) : 22
# Enter the DiabetesPedigreeFunction(0-1) : 0.6
# Enter the Age : 23
# Press 1 to Continue :-2
# Warning:Please select Defined Number!!
